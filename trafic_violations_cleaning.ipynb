# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv('/content/sample_data/traffic_violaions.csv')

# %%
df
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 52961  10/5/2011      1:55           NaN           NaN             NaN
# 52962  10/5/2011      6:43           NaN             M          1986.0
# 52963  10/5/2011      6:49           NaN           NaN             NaN
# 52964  10/5/2011      7:19           NaN             F          1986.0
# 52965       10/5       NaN           NaN           NaN             NaN
#
#        driver_age driver_race     violation_raw violation search_conducted  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52966 entries, 0 to 52965
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           52966 non-null  object
#  1   stop_time           52965 non-null  object
#  2   country_name        0 non-null      float64
#  3   driver_gender       49580 non-null  object
#  4   driver_age_raw      49588 non-null  float64
#  5   driver_age          49346 non-null  float64
#  6   driver_race         49581 non-null  object
#  7   violation_raw       49581 non-null  object
#  8   violation           49581 non-null  object
#  9   search_conducted    52965 non-null  object
#  10  search_type         2085 non-null   object
#  11  stop_outcome        49581 non-null  object
#  12  is_arrested         49581 non-null  object
#  13  stop_duration       49581 non-null  object
#  14  drugs_related_stop  52965 non-null  object
# dtypes: float64(3), object(12)
# ...

# %%
df.isna().sum()
# Out:
# stop_date                 0
# stop_time                 1
# country_name          52966
# driver_gender          3386
# driver_age_raw         3378
# driver_age             3620
# driver_race            3385
# violation_raw          3385
# violation              3385
# search_conducted          1
# search_type           50881
# stop_outcome           3385
# is_arrested            3385
# stop_duration          3385
# drugs_related_stop        1
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 286

# %%
df.drop(columns=['country_name','search_type','driver_age_raw'], inplace=True)

# %%
df
# Out:
#        stop_date stop_time driver_gender  driver_age driver_race  \
# 0       1/2/2005      1:55             M        20.0       White
# 1      1/18/2005      8:15             M        40.0       White
# 2      1/23/2005     23:15             M        33.0       White
# 3      2/20/2005     17:15             M        19.0       White
# 4      3/14/2005     10:00             F        21.0       White
# ...          ...       ...           ...         ...         ...
# 52961  10/5/2011      1:55           NaN         NaN         NaN
# 52962  10/5/2011      6:43             M        25.0       White
# 52963  10/5/2011      6:49           NaN         NaN         NaN
# 52964  10/5/2011      7:19             F        25.0       White
# 52965       10/5       NaN           NaN         NaN         NaN
#
#           violation_raw violation search_conducted   stop_outcome is_arrested  \
# 0              Speeding  Speeding            False       Citation       False
# ...

# %%
df.dropna(subset = ['drugs_related_stop'], inplace = True)

# %%
df.isna().sum()
# Out:
# stop_date                0
# stop_time                0
# driver_gender         3385
# driver_age            3619
# driver_race           3384
# violation_raw         3384
# violation             3384
# search_conducted         0
# stop_outcome          3384
# is_arrested           3384
# stop_duration         3384
# drugs_related_stop       0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().any()
# Out:
# False

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# stop_date             0
# stop_time             0
# driver_gender         0
# driver_age            0
# driver_race           0
# violation_raw         0
# violation             0
# search_conducted      0
# stop_outcome          0
# is_arrested           0
# stop_duration         0
# drugs_related_stop    0
# dtype: int64

# %%
df['stop_date'] = pd.to_datetime(df['stop_date'])

# %%
df['stop_time'] = pd.to_datetime(df['stop_time'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49171 entries, 0 to 52964
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           49171 non-null  datetime64[ns]
#  1   stop_time           49171 non-null  datetime64[ns]
#  2   driver_gender       49171 non-null  object
#  3   driver_age          49171 non-null  float64
#  4   driver_race         49171 non-null  object
#  5   violation_raw       49171 non-null  object
#  6   violation           49171 non-null  object
#  7   search_conducted    49171 non-null  object
#  8   stop_outcome        49171 non-null  object
#  9   is_arrested         49171 non-null  object
#  10  stop_duration       49171 non-null  object
#  11  drugs_related_stop  49171 non-null  object
# dtypes: datetime64[ns](2), float64(1), object(9)
# memory usage: 4.9+ MB

# %%
df
# Out:
#        stop_date           stop_time driver_gender  driver_age driver_race  \
# 0     2005-01-02 2023-04-05 01:55:00             M        20.0       White
# 1     2005-01-18 2023-04-05 08:15:00             M        40.0       White
# 2     2005-01-23 2023-04-05 23:15:00             M        33.0       White
# 3     2005-02-20 2023-04-05 17:15:00             M        19.0       White
# 4     2005-03-14 2023-04-05 10:00:00             F        21.0       White
# ...          ...                 ...           ...         ...         ...
# 52956 2011-10-04 2023-04-05 22:22:00             M        32.0       White
# 52958 2011-10-04 2023-04-05 22:36:00             F        44.0    Hispanic
# 52959 2011-10-04 2023-04-05 23:25:00             F        20.0       Black
# 52962 2011-10-05 2023-04-05 06:43:00             M        25.0       White
# 52964 2011-10-05 2023-04-05 07:19:00             F        25.0       White
#
# ...

# %%
df['stop_duration'].unique()
# Out:
# array(['0-15 Min', '16-30 Min', '30+ Min'], dtype=object)

# %%
df['search_conducted'].unique()
# Out:
# array([False, True], dtype=object)

# %%
label_encoding = {"stop_duration": {'0-15 Min':7,'16-30 Min':25, '30+ Min':40}, 
                  "driver_gender": {'M':0,'F':1}, 
                  
                 }
df = df.replace(label_encoding)

# %%
df.head()
# Out:
#    stop_date           stop_time  driver_gender  driver_age driver_race  \
# 0 2005-01-02 2023-04-05 01:55:00              0        20.0       White
# 1 2005-01-18 2023-04-05 08:15:00              0        40.0       White
# 2 2005-01-23 2023-04-05 23:15:00              0        33.0       White
# 3 2005-02-20 2023-04-05 17:15:00              0        19.0       White
# 4 2005-03-14 2023-04-05 10:00:00              1        21.0       White
#
#       violation_raw violation search_conducted   stop_outcome is_arrested  \
# 0          Speeding  Speeding            False       Citation       False
# 1          Speeding  Speeding            False       Citation       False
# 2          Speeding  Speeding            False       Citation       False
# 3  Call for Service     Other            False  Arrest Driver        True
# 4          Speeding  Speeding            False       Citation       False
#
#    stop_duration drugs_related_stop
# 0              7              False
# ...

# %%
label_encoding = {"search_conducted": {'False':0,'True':1}, 
                  "drugs_related_stop": {'False':0,'True':1}, 
                  
                 }
df = df.replace(label_encoding)

# %%
df.head()
# Out:
#    stop_date           stop_time  driver_gender  driver_age driver_race  \
# 0 2005-01-02 2023-04-05 01:55:00              0        20.0       White
# 1 2005-01-18 2023-04-05 08:15:00              0        40.0       White
# 2 2005-01-23 2023-04-05 23:15:00              0        33.0       White
# 3 2005-02-20 2023-04-05 17:15:00              0        19.0       White
# 4 2005-03-14 2023-04-05 10:00:00              1        21.0       White
#
#       violation_raw violation  search_conducted   stop_outcome is_arrested  \
# 0          Speeding  Speeding             False       Citation       False
# 1          Speeding  Speeding             False       Citation       False
# 2          Speeding  Speeding             False       Citation       False
# 3  Call for Service     Other             False  Arrest Driver        True
# 4          Speeding  Speeding             False       Citation       False
#
#    stop_duration  drugs_related_stop
# 0              7               False
# ...

# %%
df.search_conducted = df.search_conducted.replace(to_replace=[True, False], value=[1, 0])

# %%
df.head()
# Out:
#    stop_date           stop_time  driver_gender  driver_age driver_race  \
# 0 2005-01-02 2023-04-05 01:55:00              0        20.0       White
# 1 2005-01-18 2023-04-05 08:15:00              0        40.0       White
# 2 2005-01-23 2023-04-05 23:15:00              0        33.0       White
# 3 2005-02-20 2023-04-05 17:15:00              0        19.0       White
# 4 2005-03-14 2023-04-05 10:00:00              1        21.0       White
#
#       violation_raw violation  search_conducted   stop_outcome is_arrested  \
# 0          Speeding  Speeding                 0       Citation       False
# 1          Speeding  Speeding                 0       Citation       False
# 2          Speeding  Speeding                 0       Citation       False
# 3  Call for Service     Other                 0  Arrest Driver        True
# 4          Speeding  Speeding                 0       Citation       False
#
#    stop_duration  drugs_related_stop
# 0              7                   0
# ...

# %%
df['year'] = df['stop_date'].dt.year

# %%
df
# Out:
#        stop_date           stop_time  driver_gender  driver_age driver_race  \
# 0     2005-01-02 2023-04-05 01:55:00              0        20.0       White
# 1     2005-01-18 2023-04-05 08:15:00              0        40.0       White
# 2     2005-01-23 2023-04-05 23:15:00              0        33.0       White
# 3     2005-02-20 2023-04-05 17:15:00              0        19.0       White
# 4     2005-03-14 2023-04-05 10:00:00              1        21.0       White
# ...          ...                 ...            ...         ...         ...
# 52956 2011-10-04 2023-04-05 22:22:00              0        32.0       White
# 52958 2011-10-04 2023-04-05 22:36:00              1        44.0    Hispanic
# 52959 2011-10-04 2023-04-05 23:25:00              1        20.0       Black
# 52962 2011-10-05 2023-04-05 06:43:00              0        25.0       White
# 52964 2011-10-05 2023-04-05 07:19:00              1        25.0       White
#
# ...

# %%
df['day'] = df['stop_date'].dt.day
df['month'] = df['stop_date'].dt.month

# %%
df
# Out:
#        stop_date           stop_time  driver_gender  driver_age driver_race  \
# 0     2005-01-02 2023-04-05 01:55:00              0        20.0       White
# 1     2005-01-18 2023-04-05 08:15:00              0        40.0       White
# 2     2005-01-23 2023-04-05 23:15:00              0        33.0       White
# 3     2005-02-20 2023-04-05 17:15:00              0        19.0       White
# 4     2005-03-14 2023-04-05 10:00:00              1        21.0       White
# ...          ...                 ...            ...         ...         ...
# 52956 2011-10-04 2023-04-05 22:22:00              0        32.0       White
# 52958 2011-10-04 2023-04-05 22:36:00              1        44.0    Hispanic
# 52959 2011-10-04 2023-04-05 23:25:00              1        20.0       Black
# 52962 2011-10-05 2023-04-05 06:43:00              0        25.0       White
# 52964 2011-10-05 2023-04-05 07:19:00              1        25.0       White
#
# ...

# %%
df['hour'] = df['stop_time'].dt.hour

# %%
df
# Out:
#        stop_date           stop_time  driver_gender  driver_age driver_race  \
# 0     2005-01-02 2023-04-05 01:55:00              0        20.0       White
# 1     2005-01-18 2023-04-05 08:15:00              0        40.0       White
# 2     2005-01-23 2023-04-05 23:15:00              0        33.0       White
# 3     2005-02-20 2023-04-05 17:15:00              0        19.0       White
# 4     2005-03-14 2023-04-05 10:00:00              1        21.0       White
# ...          ...                 ...            ...         ...         ...
# 52956 2011-10-04 2023-04-05 22:22:00              0        32.0       White
# 52958 2011-10-04 2023-04-05 22:36:00              1        44.0    Hispanic
# 52959 2011-10-04 2023-04-05 23:25:00              1        20.0       Black
# 52962 2011-10-05 2023-04-05 06:43:00              0        25.0       White
# 52964 2011-10-05 2023-04-05 07:19:00              1        25.0       White
#
# ...

# %%
df.is_arrested = df.is_arrested.replace(to_replace=[True, False], value=[1, 0])

# %%
df
# Out:
#        stop_date           stop_time  driver_gender  driver_age driver_race  \
# 0     2005-01-02 2023-04-05 01:55:00              0        20.0       White
# 1     2005-01-18 2023-04-05 08:15:00              0        40.0       White
# 2     2005-01-23 2023-04-05 23:15:00              0        33.0       White
# 3     2005-02-20 2023-04-05 17:15:00              0        19.0       White
# 4     2005-03-14 2023-04-05 10:00:00              1        21.0       White
# ...          ...                 ...            ...         ...         ...
# 52956 2011-10-04 2023-04-05 22:22:00              0        32.0       White
# 52958 2011-10-04 2023-04-05 22:36:00              1        44.0    Hispanic
# 52959 2011-10-04 2023-04-05 23:25:00              1        20.0       Black
# 52962 2011-10-05 2023-04-05 06:43:00              0        25.0       White
# 52964 2011-10-05 2023-04-05 07:19:00              1        25.0       White
#
# ...

# %%
df.to_csv('trafic_violations.csv')
